# %% [markdown]
# <a href="https://colab.research.google.com/github/paulodowd/Webots_2021/blob/master/WLabsheets/L0_Webots_GettingStarted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Labsheet 0: Webots, Getting Started
#
# In this labsheet we will:
# - Install Webots.
# - Test the installation by opening a built-in Demo.
# - Open the Labsheet World.
# - Configuring the World for different Controllers and Arena Floors.
# - Getting Startedw with `C Programming`.
#   - If you are comfortable with C programming, you may wish to advance immediate to the next Labsheets.
#
# This labsheet is supported with a recorded lecture available to you via the Blackboard unit page.
#
# <br>
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_ArenaFloor.png?raw=true">
# </p>
# <br><br>

# %% [markdown]
# <hr><br><br><br><br>

# %% [markdown]
# ## Installing Webots
#
# Webots is a free, open-source robotics simulator.  We will be using Webots to practice some robotics programming concepts, and later you will may use Webots as the basis of conducting your own robotics experiment.
#
# You can find, download and install Webots from the following URL:
#
# <a href="https://cyberbotics.com/#download">Download Webots</a>

# %% [markdown]
# <hr><br><br><br><br>

# %% [markdown]
# ## Loading a Demo
#
# In this section we will load a Demo built in within Webots.  In the future, loading a built in Demo is a good way to get started on your own projects.
#
# 1) Load the Webots application on your computer.
#
# 2) Select `File -> Open Sample World..`
#
# 3) You should be presented with a new dialogue window like the following. Expand the menus `gctronic -> e-puck` and then open the file `e-puck_line_demo.wbt`:
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_SampleWorldDialogue.png?raw=true">
# </p>
#
# <br><br>
# 4) You should now be able to see the Webots User Interface which will look similar to the below:
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_UI.png?raw=true">
# </p>
#
# <br><br>
# 5) To test the simulator, press the play icon in the top toolbar of the inteface.  You should see the small robot move and follow the line.
#
# 6) At this point, you may wish to click on the visualisation and explore how to operate the visual scene.  You could also explore the control icons in the top toolbar to reset the simulation.
#
# 7) At this point, you may wish to explore the settings and options for Webots to configure the simulator for your system.  In particular, if your computer has poor performance, you can decrease the graphical settings of the simulator by navigating to `Tools -> Preferences -> OpenGL`, to see the following dialogue:
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_Settings.png?raw=true">
# </p>
#
# To improve performance:
# - set the options to `Low` or `Disabled` where appropriate.
# - set Max Texture Filtering to 0
# - tick the boxes to `disable shadows` and `disable anti-aliasing`

# %% [markdown]
# <hr><br><br><br><br>

# %% [markdown]
# ## Open the Labsheet World
#
# The following steps describe how to open the world created for these Labsheets, available on Github.
#
# Navigate to the <a href="https://github.com/paulodowd/Webots_2021">Unit Github Repository</a>, and download the Webots World zip file named `Webots_Labs.zip` (<a href="https://github.com/paulodowd/Webots_2021/raw/master/WebotsWorld/Webots_Labs.zip">here</a>)
#
# Extract this zip file into a good known location on your computer (e.g., within your Documents folder).
#
# Witin your newly created folder, you should see two sub-folders:
# - worlds
# - controllers
#
# These files contain the basic outline of a C program witin `controllers` and a definition of the simulated world within `worlds`.
#
# Within the folder `controllers`, you will see a sub-folder called `labsheet_x`.  It is recommended that you create copies of this folder and name them labsheet_1, labsheet_2, etc.  It is recommended you also rename the `.c` file from labsheet_x to the same name as the parent folder (e.g., sub-folder `labsheet_1` to contain `labsheet_1.c`). You can do this as you begin work on each labsheet.
#
# If you navigate into the `worlds` folder, you can open `labsheet_x.wbt` with Webots.  Webots should load a simulated world which looks like the following:
#
# <br>
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_ArenaFloor.png?raw=true">
# </p>
# <br>

# %% [markdown]
# <hr><br><br><br><br>

# %% [markdown]
# ## Configuring the World
#
# In this section we will configure the simulated world to utilise a different Controller.

# %% [markdown]
# ### Open a Controller (C program)
#
# 1) In the right most pane, click the "Open an existing text file" icon in the top row of icons.
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_OpenC.png?raw=true">
# </p>
#
# 2) Select the `.c` file within your current working folder.  E.g., if you have created a folder named `labsheet_0`, open `labsheet_0.c`.  If you have not created these folders and files, you can use the default templates `labsheet_x` and `labsheet_x.c`.
#
# 3) Before you compile the code, you may need to clean the build environment (clear temporary files).  Press the brush icon once:
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_CleanBuild.png?raw=true">
# </p>
#
# 4) Above the right most pane, press the `Build the current project` icon in the top row of icons.
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_BuildCurrent.png?raw=true">
# </p>
#
# 5) In the bottom most pane labelled `Console - All`, you should see some text output which looks similar to the below.  This text output shows the instruction executed to compile your program (`make -j 6`), then the steps taken (`compiling...` and `linking...`), and finally the status (`Build Finished`).  If you make any errors when you write your code, the error message will show up in this console in red after you press the `Build the current project` icon.
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_ConsoleMakeOutput.png?raw=true">
# </p>
#
# 6) You will likely be asked if you wish to `reload` or `reset` your world.
# - **Reload**: this will restore the e-puck to the initial position as defined in your world file.
# - **Reset**: this will reset the status of your e-puck and the world, but not change any other details.  For example, if your e-puck robot has moved away from the normal starting position, the e-puck will be reset and the clock will be reset to 0, but the e-puck will not be moved back to the normal start position.
#
# 7) During your working, you may be asked if you want to save changes to the world file (`.wbt`).  If you select yes, then any changes made to the world will be saved and made default for the next time you open the file.  This includes:
# - which controller the e-puck will use.
# - where objects in the world are placed and how they are posed.
# - where the e-puck starts and how it is posed.

# %% [markdown]
# ### Select the Controller to Use
#
# To ensure your simulated e-puck will run the correct version of your code, complete the following steps.
#
# 1) In the left most pane, expand and navigate the list entries as per the graphic below:
#
# - `DEF EPUCK E-puck`
# - controller "labsheet_x"
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_EpuckControllerLP.png?raw=true">
# </p>
#
# 2) Click on the `select...` button below the list.
#
# 3) You will be presented with a new dialogue to select the name of your controller.  Because you compiled the controller in the last step, you should be able to find the same name in this list.  Select the appropriate name, and press OK.
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_EPuckControllerSelect.png?raw=true">
# </p>

# %% [markdown]
# ### Configuring the Arena Floor
#
# If the arena floor of your simulated world has not rendered properly, complete the following steps:
#
# 1) In the left most pane, expand the list entries as per the graphic below:
# - `RectangleArena "rectangle arena"`
# - `floorAppearance PBRAppearance`
# - `baseColorMap ImageTexture`
# - `url`
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_RectangleArena.png?raw=true">
# </p>
#
# 2) Download the Labsheets line following challenge map from github, <a href="https://github.com/paulodowd/Webots_2021/blob/master/WebotsFloor/test_floor.png?raw=true">available here</a> and save to a known location on your computer.
#
# 3) Use the button `Select...` to navigate to and select the line following challenge map you just downloaded.  You should see the arena floor of the simulation change to look like the following:
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_ArenaFloor.png?raw=true">
# </p>
#
# 4) If you wish to create your own Arena Floors, it is recommended:
# - you keep to a `1024 x 1024` pixel image in `.png` format.
# - you keep path line widths to `10` pixels.
# - an `.svg` image is <a href="https://raw.githubusercontent.com/paulodowd/Webots_2021/master/WebotsFloor/test_floor.svg">available on Github</a> (right-click, save as...), which is relatively easy to edit with an application such as <a href="https://inkscape.org/release/inkscape-1.1/">Inkscape</a> and to export as a 1024x1024 .png file (96 dpi).

# %% [markdown]
# <hr><br><br><br><br>

# %% [markdown]
# ## The Simulator Architecture
#
# Before we investigate the C language in more detail, it is useful to first understand the general premise of how the Webots simulation operates.  The below image illustrates the `architecture` of the simulator:
#
# <p align="center">
# <br>
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_SimulatorController.png?raw=true">
# <br>
# </p>
#
# In the above, we can conceptually seperate the operation of the simulator versus the robot controller.  Because we are simulating a process over time, it is necessary to "step" (advance) the simulator `discretely` (at fixed intervals).  When the simulator is stepped, the sensors are updated for the new environment status, and the actuators are provided their new instructions.
#
#
# <p align="center">
# <br>
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_UpdateCycle.png?raw=true">
# <br>
# </p>
#
# Whilst it is possible to step the simulator forwards within any part of your code (as illustrated below), it is extremely likely you will develop bugs and erroneous behaviours in your simulator robot.  This is because time will be able to advance from any part of your program, and there will be a loss of any general synchronisation to your program.
#
# <p align="center">
# <br>
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_WrongSimStep.png?raw=true">
# <br>
# </p>
#
# Instead, it is better to write a controller to not interfere with how time is incremented  - similar to the way real time advances regardless of our human actions.  Therefore, you should write your controller so that the `loop()` function returns at every time interval, and for your controller to re-evaluate present circumstances at every time interval.
#
#
# This is not especially convenient, however, it is much closer to how we would develop code for an embedded computing platform such as a microcontroller.

# %% [markdown]
# <hr><br><br><br><br>

# %% [markdown]
# ## Getting Started with C Programming
#
# We can learn some C programming from within the Webots User Interface.  Following the steps above, you should have Webots configured with the simulated world intended for the labseets, and a controller source code file named `labsheet_x.c` (or as you renamed it).
#
# When we program in C, we take 3 essential steps:
# - write source code.
# - compile source code into machine code.
# - execute machine code.
#
# Therefore, every time we make a change to a C program we must move through these 3 steps.  In Webots, we will use the pane on the right hand side, a text editor, to make changes to the code.  To see the effect of your changes we will need to then use the `Build the current project` icon to compile the code:
#
# <p align="center">
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_BuildCurrent.png?raw=true">
# </p>
#
# If the code compiles without any errors, we can then execute the code using the Webots `play` icon for the simulator, and view the behaviour of the robot (if any).  If we are not commanding the robot to operate, we might still use the text console at the bottom of the screen to receive text-based information from the simulator and robot.
#
# **You might find that the best way for you to learn is to start exploring the code immediately.  You can try changing the code to see what works, and to see how the performance is altered.  If something does go very wrong, you can always repeat the prior sections to restore your simulation back to the normal configuration from the zip file.  We will progressively build up a robot controller across the Labsheets.**
# <p><br></p>

# %% [markdown]
# ### Why are we using C?
# You may have noticed that Webots supports programming in Python.  If you can program in Python already, well done, that is great!  In this unit, we are aiming our learning towards skills for microcontroller development.  In microcontrollers and embedded programming, C is still the dominant programming language because it provides close access to hardware, and it is the root understanding of other languages such as C++.  In this unit of study, we will gain some basic C programming experience which can be built upon later in your career.  Learning C through Webots will also make it easier for you to work with common platforms such as the Arduino.  Learning to program in C is a good thing!
# <p><br></p>

# %% [markdown]
# ### Understanding C
#
# First of all, let's look at the `labsheet_x.c` source file and draw some understanding from it's existing content and structure.  If you quickly read the whole source code file in over view, you'll notice that it has the following sections:
# - Library Includes
# - Global Variables
# - Function Prototypes
# - Main thread
# - Supporting functions:
#   - Setup()
#   - Loop()
#
# In general, you can expect your code to keep this structure but to expand it with further supporting functions.  The most important part of this program is the `main thread` and the `supporting functions`.  At a glance, these will operate as per the following illustration:
#
#
# <p align="center">
# <br>
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_BasicFlow.png?raw=true">
# <br>
# </p>
#
# The following sections will review each part of the program in turn.
# <p><br></p>

# %% [markdown]
# #### Comments
#
# ```c
# /*********************************************
#  Library Includes
#    You can use other C libraries
# **********************************************/
# #include <stdio.h>
# #include <webots/led.h>
# #include <webots/motor.h>
# #include <webots/robot.h>
# #include <webots/distance_sensor.h>
# #include <webots/position_sensor.h>
# ```
#
# In the above code extract, we can see that there is some normal looking English text, and then more abstract C code.  The element in green has been coloured green because it is a comment.  A comment is not compiled or executed by the compiler.  You should use comments to make notes to yourself, and to other people who will read your code.
#
# You will find that you quickly forget why you wrote some code or how it works, so leave comments!  This will also help your tutors when they come to help you.  It is also good practice to write a comment detailing how you will solve the problem, **before** you write the code.  This will help you to think problems through.
#
# In `C` we can create a comment in two ways:
#
# ```c
# /* this is
#    one way
#  */
#
# // This is another way.
#
# ```
#
# In the first method, we open a comment with `/*`, and close the comment with `*/`.  This is convenient to remove multiple lines of code from your program, if you think they are causing a problem. It is also useful to leave large comments in your code, such as an explanation.
#
# The second method is quick and short, and will only allow you to make a comment on a single line.  You'll see lots of these throughout the rest of the source code.
#
# You can run into problems if you attempt to use `/*  //   */` (mixing the comment styles, a comment inside a comment), so it is best to keep their use seperate.
# <p><br></p>

# %% [markdown]
# #### Library Includes
#
# The lines of code which look like:
#
# ```c
# #include <stdio.h>
# ```
# are referencing external library code into your program.  In effect, they will "copy" code into your program when you compile it.
#
# The existing 6 `#include` made at the top of this `labsheet_x.h` source file are the essential files you need to include to write your code.  These external source files generally contain code to help you to interface with the simulator, or to perform standard operations within the C language.  `<stdio.h>` for example, will allow you to use standard C function <a href="https://www.cprogramming.com/tutorial/printf-format-strings.html">`printf()`</a> to report text to the `Console - All` pane at the bottom of the Webots user interface - this is a really useful function to gain information on your robot's state!
#
# Depending on the code you write, you may find that you include more libraries to perform useful functions.  If you use the internet to help you to find programming solutions, make sure you also check if the source code you find needs more libraries included.
# <p><br></p>

# %% [markdown]
# #### Global Variables
#
# From `labsheet_x.c`, the next section of code looks like the following code extract.  Note that, once again, you do not need to change or edit any of the below code, but you may wish to add to it later.
#
# ```c
# /*********************************************
#  Global variables.
#    Declare any global variables here to keep
#    your code tidy.
# **********************************************/
#
# // simulation time step is 32ms
# #define TIME_STEP 32
#
# // 3 IR ground sensors
# #define NB_GROUND_SENS 3
# #define GS_LEFT 0
# #define GS_CENTER 1
# #define GS_RIGHT 2
# WbDeviceTag gs[NB_GROUND_SENS]; /* ground sensors */
# unsigned short gs_value[NB_GROUND_SENS] = {0, 0, 0};
#
# // Motors
# WbDeviceTag left_motor, right_motor;
#
# // LEDs
# #define NB_LEDS 8
# WbDeviceTag led[NB_LEDS];
#
# // Proximity Sensors
# #define NB_PS 8
# WbDeviceTag distance_sensor[NB_PS];
#
# // Position Sensors (encoders)
# WbDeviceTag left_position_sensor, right_position_sensor;
#
# ```
# The above are all referred to as `Global Variables` because they are outside of any `function`.  We will investigate a `function` soon.  As a short explanation, a `Global Variable` will exist for the entire duration of your program, and be will also be visible to all other parts of your program.  This has two disadvantages:
# - global variables will use up computer memory and are considered inefficient.
# - global variables can cause errors and bugs if they conflict with other variables elsewhere in your program.
# <p><br></p>

# %% [markdown]
# #### Global Variables: #define
# To look more closely:
# ```c
# #define TIME_STEP 32
# ```
# The above is called a `#define` ("hash-define"), and these can be thought of as a `find-and-replace` operator in your code. If your code has a data item which is used in many places and does not change, a `#define` is a good idea to use.  A `#define` is then referenced elsewhere in code by the reference (in this case `TIME_STEP`), and the compiler will substitute in the value (in this case, `32`).
#
# We can see this `find-and-replace` immediately in effect with the lines:
# ```c
# #define NB_GROUND_SENS 3
# ...
# unsigned short gs_value[NB_GROUND_SENS] = {0, 0, 0};
# ```
# The above code creates a space in computer memory to store 3 `unsigned short` variables.  The value `3` comes from the `#define NB_GROUND_SENS 3` line of code.  The reference `NB_GOUND_SENS` was chosen to briefly represent "**N**um**b**er of **ground** **sens**ors".  The 3 memory elements named `gs_value` are then assigned the initial values of 0 (` = { 0, 0, 0 }`).  We will investigate `variables` in more depth soon.
#
# `#define` are a good idea to use because:
# - they allow you to set constants in a convenient location in your program.  Note that, this means we **would not** use a `#define` for a value we expect to change within the program operation.
# - they help to reduce errors and bugs, because you do not need to find all the values throughout your code - you can just change the `#define` value at the top of your program, meaning you only need to change something in a single location (reducing human error).
# - they can be used to make your code more human-readable, also helping to reduce errors and bugs.
# <p><br></p>

# %% [markdown]
# #### Global Variables: Special Cases
#
# We can see several lines that look similar to:
#
# ```c
# WbDeviceTag gs[NB_GROUND_SENS];
# WbDeviceTag left_motor, right_motor;
# WbDeviceTag distance_sensor[NB_PS];
# WbDeviceTag left_position_sensor, right_position_sensor;
# ...
# ```
# Hopefully you can notice a pattern - they all start with `Wb`.  Throughout the source code, you will notice highlighted code (yellow within Webots) that starts with `Wb` or `Wb_`.  These elements of code are keywords or functions relating uniquely to **W**e**b**ots.    These are all non-standard parts of the C programming language.
#
# The above four lines are all creating a reference (a name to access) the robot devices (the ground sensor, the motors, the distance sensors, the motor position encoders - respectively).  In these cases, the text starting with `Wb...` is the keyword to the compiler, and the next string of characters (e.g. left_motor) becomes the reference (name) we will use in the code.
#
# In C, you will see this format repeated often.  The format in question is:
# ```c
# WbDeviceTag  left_motor;
# <type>       <reference>
# ```
#
# For example, we will soon come across many types of `variable`, which all take up different amounts of computer memory.  When these are defined in code, they will look something like:
#
# ```c
# float  my_float_variable; // e.g. 0.001 or -99.9954
# int    my_int_variable;   // e.g. -5 or 255
# char   my_char_variable;  // e.g.  a or e
# bool   my_bool_variable;  // e.g. false or true
# <type>  <refrence>
# ```
# In the above, we can see the same pattern - first the type is declared (float, int, char, bool) which indicates how much memory is to be allocated.  And then the reference is declared (the name assigned) so that elsewhere in code we can assign or read a value from that allocated memory.  Imagine - if we didn't create a reference (name), we would never be able to find the allocated memory again; and if we didn't declare the type, the compiler wouldn't know how much memory to set aside (all of it?  just one byte?).
#
# These `Wb` keyword references are later initialised (configured) in the `setup()` function, which we will look at later.  These `Wb` keywords and functions are the only non-standard parts of C you should encounter.

# %% [markdown]
# #### Function Prototypes
#
# ```c
# /*********************************************
#  Function prototypes.
#    Tells the C compiler what functions we have
#    written within this source file
# **********************************************/
#
# // One time setup, at beginning of simulation
# void setup( );
#
# // Controller to be called again and again.
# void loop( );
#
# // An example function that doesn't do anything
# float doNothing( float f );
# ```
#
# The above code indicates to the compiler which additional functions have been written beyond the `#include` libraries.  Creating function prototypes is also useful for the readibility of your code - it makes it clear what can be achieved with your code at the top of the source file, a bit like a contents page.
#
# The function prototype has a similar format to the variable declaration we reviewed just prior.   Notice:
# ```c
# // One time setup, at beginning of simulation
# void   setup();
# <type> <name>
# ```
# The above line of code first has a type, and then a name which will we use to call the function (operate or execute it).  The functions `setup()` and `loop()` both have the type `void` prefixed in their declaration - this means that the function will not return any data as a result of it's operation.
#
# ```c
# // An example function that doesn't do anything
# float doNothing( float f );
# ```
# The above function prototype has a return type of `float`.  This means that when this function is called, it will return a value back.  This can be used to assign a the result of a function back into a variable.
#
# ```c
# // An example of assigning the result of
# // a function call.
# float a;
# a = doNothing( 10 );
#
# ```
#
# The example function `doNothing(float f)` also has a declaration inside the parentheses (` float f`).  When we call a function, we often want it to do something or process some provided data.  When we pass some data to a function these are called `arguments`.  It is possible to have no arguments, such as the `setup()` and `loop()` examples.  It is also possible to have more than one argument given to a function.
#
# ```c
# float x;
# float c;
# x = 10;
# c = addTwoNumbers( x, x );
#
# // A very simple function example.  Takes two float
# // values as input, and returns their sum.
# float addTwoNumbers( float a, float b ) {
#   float result;
#
#   // Functions should be used to encapsulate common
#   // operations in your code.  Here, it is the sum
#   // of two numbers.
#   result = a + b;
#
#
#   // For examples sake, this assignment would not
#   // change the original value of x.  Arguments
#   // provide only the value, not access to the
#   // variable.  Arguments can be treated as
#   // temporary variables.
#   a = 20;
#
#   // Pass back the value of result.
#   return result;
# }
#
# ```
#
# It is important to know that the `function prototype` at the top of your source file must match the actual function declaration else where in your code.  For example:
#
# ```c
# // An example function that doesn't do anything
# void doNothing( int f );
#
# // The function declaration
# void doNothing( float f ) {
#   return;
# }
# ```
# The above code will not compile, because the arguments have different types declared (`float` vs. `int`).  Common compile errors with functions are:
# - if the `argument types` are different
# - if the `return types` are different
# - if the `functions names` are spelt differently
# - if the function declaration or prototype is repeated more than once.
#
# By now, you will likely feel like there is a lot to remember.  With practice, you will encounter common errors and learn to solve them quickly.  In fact, the errors you receive from the compiler should be regarded as a helpful friend!

# %% [markdown]
# #### Main Thread
#
# In this section we will review the `Main thread`.  The main thread is the heart of every `C` program.  The main thread is standard, and you should expect to always find a main thread within a C program.
#
# To explain the main thread as plainly as possible: every program that we run on a computer needs an `entry point`.  That is, when we ask our computer (a PC, Mac, microcontroller, microprocessor, etc) to run the program, what is the first part of the program to be run?  In C, we expect this to be the `main` function.  From the main function, our code can then call other functions, iterate (loop), call other programs, and many other operations.  Generally speaking, if the program finishes without any errors, the main function will return the value `0`, which is recognised as "success".
#
# For our work within  Webots, we will be able to leave the main function exactly as it is presented in the source file and this labsheet.  During your working, it is expected that you'll develop further code to run from the `setup()` and `loop()` functions, which we will review soon.  In which case, the main function serves the following purpose, and does not need any changes:
# - to provide an entry point to begin the simulation
# - to call our `setup()` function, to prepare our robot controller
# - to iteratively call our `loop()` function:
#   - to update our robot controller, and send robot commands
#   - to stop iterating when the simulation is ended.
# - to provide an exit point, to finish the simulation
#
# It is important to be aware that the main thread declaration can take different forms, and in this example it is nearly as simple as it can be:
#
# ```c
# /*********************************************
#  Main Thread.
#    This is the main thread of our C program.
#    For this unit of study, it is recommended
#    you do not alter the structure of main()
#    below.  Instead, you should work from the
#    functions setup() and loop().  You are
#    free to create your own useful functions.
# **********************************************/
# int main(void) {
#
#   // Initialise Webots - must be done!
#   wb_robot_init();
#
#   // Code called here happens before the
#   // simulator begins running properly.
#   setup();
#
#   // Run the simulator forever.
#   while( wb_robot_step(TIME_STEP) != -1 ) {
#
#     // Call robot controller loop
#     loop();
#   }
#
#   // Ask Webots to stop nicely
#   wb_robot_cleanup();
#
#   // Done.
#   return 0;
# }
# ```
#
# If you are quick, the first thing you might notice is that the `main` function is created without a prototype earlier in our source file.  This is because the `main function` is a standard feature of a C program, and it is expected regardless.  When you learn to program, you will come across special cases such as this.
#
# Second, you may apply previous discussion to notice that our main function has a `return type` of `int`, meaning it should provide a whole integer number of either positive or negative value when  it finishes.   If we read to the bottom of the code extract above, we also see the line `return 0;` which conforms to our expectation.  Therefore, the complete procedural operation of our program is contained within `main`, although we can expect it to call other functions, to iterate, and quite likely operate in a non-deterministic way.
#
# Third, you may notice that the arguments of the main function are declared simply as `(void)`.  This indicates to the compiler that the main function will not receive any input arguments - no data will be given to the main thread at the beginning of the program.  If you explore other C programs, you will likely find some typical argument lists to receive data when the program is run.  In our case, we do not need this functionality.
#
# A final general observation in overview is that you main function is `encapsulated` with curly-braces `{ }`.  In C, code within a function needs to be written within these curly-braces, and it is also important that the braces match.  For example:
#
# ```c
# int main( void ) {
#
#   //...
#
#   return 0;
# }
# }
# ```
# The above code will cause a compile error because we have opened a curly-brace after the `function name`, but then provided two closing curly-braces.  When you receive this type of error, the compile will often report an error message for another line of code, even if the line of code referenced is correct!  This happens because the curly-brace interferes with the order of the code being read by the compiler.  As a rule-of-thumb, it is good practice to check all your parentheses and curly-braces whenever you are in doubt.
#
# Curly-braces must be opened and closed in a pairwise fashion.  When used correctly, it becomes clear what code exists within which function, and not confused with another function.  You may find C to be very pedantic (requiring exactness!) and annoying, but with experience it becomes reassuring.  Do not be afraid of error messages from the compiler, they will help you.
#
# We will also see that curly-braces are used to `encapsulate` code within other constructs such as selection statements (`if()`, `switch()`, etc.) and iteration (`for()`, `while()`, etc.)
#
# The first line of code within our main function is:
#
# ```c
#   // Initialise Webots - must be done!
#   wb_robot_init();
# ```
#
# As mentinoed befored, we can see this function call is prefixed with `wb_`, which tells us it is a built-in function for operating the Webots simulator.  In this case, `wb_robot_init()` is a necessary call to begin the simulation process, and we don't have a choice about whether to include it or not - you will always need to have this line of code at the beginning of your main function.  If you are interested, further information can be found in the <a href="https://cyberbotics.com/doc/reference/robot#wb_robot_init">Webots Documentation</a>.
#
# The next line of code looks like:
#
# ```c
#   // Code called here happens before the
#   // simulator begins running properly.
#   setup();
# ```
#
# This is a call to the function we prototyped earlier.  We have not reviewed the actual function declaration yet.  Just from this line, we can see that `setup()` takes no arguments, and because we do not assign a value from the function call, we could assume it does not have a useful return type.
#
# We will be using the `setup()` function to set up the robot devices and any variables prior to the robot activity.  For instance, you might want to ensure that your robot believes it is as the location co-ordinates `x=0, y=0` whenever it is activated.  This `setup()` function is called by the main function before we transition to the iterating simulation proper. A simple illustration of this `program flow` is below:
#
# <p align="center">
# <br>
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Webots_SimulatorController.png?raw=true">
# <br>
# </p>
#
# The next element of code is a loop which will execute until the simulation is stopped:
#
# ```c
# while( wb_robot_step(TIME_STEP) != -1 ) {
#     //...
# }
# ```
#
# Here the construct of a `while()` loop is used to perform the code encapsulated within the curly-braces until a condition is met.  In this line of code, the `condition` is specified as:
#
# ```c
#   wb_robot_step(TIME_STEP) != -1
# ```
#
# The above line of code is operating the Webots simulator, and instructing it to advance the simulation by the quantity of time `TIME_STEP`.  At the top of our source code file, we used a `#define` statement to set the value of `TIME_STEP` - what was this?
#
# When the command wb_robot_step cannot be executed, it returns the error signal, the value `-1`.  Our while loop `conditional logic` is therefore "whilst the `wb_robot_step` command does not return an error...".  Our `while()` loop will continue to repeat until the simulator cannot be stepped (time advanced) any more.  The error signal `-1` will occur if you stop the simulator, quit Webots, or another program error occurs.  If you are interested, more information on wb_robot_step can be found in the <a href="https://cyberbotics.com/doc/reference/robot#wb_robot_step">Webots Documentation</a>.
#
# The line of code within our `while()` loop is:
# ```c
#     // Call robot controller loop
#     loop();
# ```
# This line of code calls the function we have prototyped called `loop()`.  You will write your robot controller code to operate when loop is called.  We will review `loop()` in the next section.
#
# Our main function ends in the following way:
#
# ```c
#   // Ask Webots to stop nicely
#   wb_robot_cleanup();
#
#   // Done.
#   return 0;
# ```
#
# Here we can see another call to a built-in function of Webots, `wb_robot_cleanup()`, which ensures that the simulation ends properly and the robot is deactivated. If you are interested, more information is available in the <a href="https://cyberbotics.com/doc/reference/robot?tab-language=c#wb_robot_cleanup">Webots Documentation</a>
#
# Finally, the line `return 0;` ends the C program with the signal of successful completion (`0`).
#
# We can therefore observe that observe that the `main()` function co-ordinates the overall operation of our intended program.  You should use setup() and loop() to define the operation of your robot controller.

# %% [markdown]
# #### Supporting Functions: Setup
#
# The `setup()` function runs **once** before your controller is enabled on your simulated robot.  Therefore, setup should be used to initialise any state variables (e.g, position).  Presently, the setup() function has been completed with **essential** code to configure your robot for the labsheets.  Therefore, you should not remove any code from the setup() function, although you may wish to add your own code at the end (indicated with a comment).
#
# We will investigate each part of setup() in turn. This will also allow us to explore some more features of a function within C.
#
# ```c
# /*********************************************
#  setup()
#    Use this function to setup any variables
#    or robot devices prior to the start of your
#    simulation.
# **********************************************/
# void setup() {
#
#   // Initialise simulation devices.
#   char name[20];
#   int i;
#
#   // Setup LEDs
#   for (i = 0; i < NB_LEDS; i++) {
#     sprintf(name, "led%d", i);
#     led[i] = wb_robot_get_device(name); /* get a handler to the sensor */
#   }
#
#   // Setup Ground Sensors
#   for (i = 0; i < NB_GROUND_SENS; i++) {
#     sprintf(name, "gs%d", i);
#     gs[i] = wb_robot_get_device(name); /* ground sensors */
#     wb_distance_sensor_enable(gs[i], TIME_STEP);
#   }
#
#   // Setup motors
#   left_motor = wb_robot_get_device("left wheel motor");
#   right_motor = wb_robot_get_device("right wheel motor");
#   wb_motor_set_position(left_motor, INFINITY);
#   wb_motor_set_position(right_motor, INFINITY);
#   wb_motor_set_velocity(left_motor, 0.0);
#   wb_motor_set_velocity(right_motor, 0.0);
#
#   // get a handler to the position sensors and enable them.
#   left_position_sensor = wb_robot_get_device("left wheel sensor");
#   right_position_sensor = wb_robot_get_device("right wheel sensor");
#   wb_position_sensor_enable(left_position_sensor, TIME_STEP);
#   wb_position_sensor_enable(right_position_sensor, TIME_STEP);
#
#   // Setup proximity sensors
#   for (i = 0; i < 8; i++) {
#
#     // get distance sensors
#     sprintf(name, "ps%d", i);
#     distance_sensor[i] = wb_robot_get_device(name);
#     wb_distance_sensor_enable(distance_sensor[i], TIME_STEP);
#   }
#
#   // You can add your own initialisation code here:
#   // ...
# }
# ```
#
# The setup function begins with the following lines:
#
# ```c
# void setup() {
#
#   // Initialise simulation devices.
#   char name[20];
#   int i;
#
# ```
#
# Here we see the function name declaration, which matches the prototype set earlier.  Therefore, we do not expect the function to return any data value, nor do we expect the function to receive any arguments.
#
# The first two lines of encapsulated code declare new variables, `name` and `i`.  Because these variables are declared inside of this function (they are held within the curly-braces) they will only exist within the function whilst it executes.  Or, to put this another way: when this function finishes these variables will be deleted.  These are referred to as `local variables`.
#
# The variable declaration `char name[20];` creates an `array` in memory.  An array is consecutive multiples of the same `data type`.  Here, the data type is declared as an `char`, and the number inside the square brackets indicates that enough space will be reserved to store `20` consecutive `char` variables.  Later, read and write operations can be made by referencing the variable, and inserting a number inside the square brackets to select the element:
#
# ```c
# // An example of reading and writing an array
# // element.
# // Here, element 10 is read, and its value is
# // assigned (written) into element 0 of the
# // same array.
# my_array[0] = my_array[10]
# ```
#
# In the rest of `setup()`, `name` is used to construct the device name from the Webots Documentation, so that we can configure the C program to access the simulated robot devices.  `i` is used as a place to store a number we will increment as an index.  These are better explained by looking at the next section of code within setup():
#
# ```c
#   // Setup LEDs
#   for (i = 0; i < NB_LEDS; i++) {
#     sprintf(name, "led%d", i);
#     led[i] = wb_robot_get_device(name); /* get a handler to the sensor */
#   }
# ```
#
# The above code utilises a `for()` loop.  A for loop is always written with 3 operators within the parentheses.  These are a `start condition`, `end condition`, and `operator`.  The foor loop is set as:
#
# ```c
# for (i = 0; i < NB_LEDS; i++) {
# ```
# - First element: we utilise the variable `i`, and give it a start condition of 0.
# - Second element: we set the end condition to be when `i` is equal to or exceeds `NB_LEDS` (you can also read this as, "continue whilst `i` is less than `NB_LEDS`").
#   - we set the value of `NB_LEDS` using a `#define` at the top of our source code file - what was the value?
# - Third element: the variable `i` is incremented by `1`.  The `++` operator in C is short-hand for `i = i + 1` (where `i` could be another variable, where appropriate).
#
# Therefore, our for loop will repeat the encapsulated code from 0 up until `i` is equal to the value of `NB_LEDS`.
#
# The next line of code uses the standard C function `sprintf()`, which can be used to build up strings (lots of characters, words or sentences):
#
# ```c
#   sprintf(name, "led%d", i);
# ```
#
# This line of code is necessary to build up the name of the device we are going to setup.  Here, the text string `led` is combined with the value of the variable `i`.  The `%d` special character indicates that an integer value will be replaced into the text string.  Another special character is `%f` for inserting a floating point number.
#
# ```c
# led[i] = wb_robot_get_device(name); /* get a handler to the sensor */
# ```
#
# The next line, as above, then issues a Webots built-in function call to get the simulated robot device.  This is assigned to the variable `led[i]`.  In the rest of the code, we can read and write to the `led[ ]` variable to control the state of the LEDs of the robot during the simulation.
#
# This process of building a text string, and then registering a device to a variable, is repeated through the `setup()` function.

# %% [markdown]
# <hr><br><br><br><br>

# %% [markdown]
# #### Supporting Functions: Loop
#
# ```c
# /*********************************************
#  loop()
#    Use this function to build the structure of
#    your robot controller.  Remember that we
#    expect this function to be called again and
#    again (iteratively).
# **********************************************/
# void loop() {
#
#   // Report current time.
#   printf("Loop at %.2f (secs)\n", wb_robot_get_time() );
#
#   // Get latest ground sensor readings
#   gs_value[0] = wb_distance_sensor_get_value(gs[0]);
#   gs_value[1] = wb_distance_sensor_get_value(gs[1]);
#   gs_value[2] = wb_distance_sensor_get_value(gs[2]);
#
#   // Report ground sensor values
#   printf("Ground sensor values: \n");
#   printf(" 0: %d\n", gs_value[0] );
#   printf(" 0: %d\n", gs_value[1] );
#   printf(" 0: %d\n\n", gs_value[2] );
#
#   // Call a function as an example
#   // Passing the value 0 into the function
#   doNothing( 0 );
# }
#
# ```
#
# The above code taken from the template provides an example `loop()` routine.
#
# ```c
#   // Report current time.
#   printf("Loop at %.2f (secs)\n", wb_robot_get_time() );
# ```
#
# Above, `printf()` is used to place text into the console of the Webots simulator (the central pane at the bottom of the graphical interface).  This console and using `printf()` is the best way to inspect the state of variables within your controller whilst it is working.
#
# ```c
#   // Get latest ground sensor readings
#   gs_value[0] = wb_distance_sensor_get_value(gs[0]);
#   gs_value[1] = wb_distance_sensor_get_value(gs[1]);
#   gs_value[2] = wb_distance_sensor_get_value(gs[2]);
#
# ```
#
# The above lines peform a read of the e-puck ground sensors, and store the values into the array `gs_value`.  These can then be used as the basis of decisions and operation for your e-puck robot.
#
# ```c
#   // Report ground sensor values
#   printf("Ground sensor values: \n");
#   printf(" 0: %d\n", gs_value[0] );
#   printf(" 0: %d\n", gs_value[1] );
#   printf(" 0: %d\n\n", gs_value[2] );
# ```
#
# The above lines report the sensor values to the console at the bottom of the graphical interface.
#
# The main code of your program should be written in the `loop()` function.  Aim to have your `loop()` code to return and be called again - to operate iteratively.  The below illustration shows an iterative approach to counting up to 10:
#
# <p align="center">
# <br>
# <img src="https://github.com/paulodowd/Webots_2021/blob/master/images/Arduino_CountToTen.png?raw=true">
# <br>
# </p>
#
# Note that, in the above illustration, `loop()` would need to be executed 10 times for `countToTen()` to return `true`.  Like this, `loop()` would be able to execute some other code whilst the count to 10 had not been completed.  In contrast, a loop operator within `countToTen()` (such as the example below) would have blocked `loop()` from running for a (very) short duration:
#
# ```c
# // An example of a blocking function
# bool countToTen() {
#   int i;
#   i = 0;
#
#   // microcontroller will be repeating
#   // this 10 times
#   while( i < 10 ) {
#     i = i + 1;
#   }
#   return true;
#
# }
# ```
#
# In general, the example of counting to 10 would not be of significant detriment to the system.  However, hardware access or iteration over large arrays can be a problem.
#
# Software for a robotic system will get complicated very quickly.  Therefore, it is better to take an approach with a clear `execution flow` that follows a consistent method.  Your code will be more readable if the expected flow of your program always iterates through `loop()`.  This will also make your code easier to extend with more functionality.
#
# In the future, your `loop()` routine might be as readable as the below example, giving a complete general overview of the capability of your robot:
#
# ```c
# void loop() {
#
#   updateSensors();
#   robot_state = updateRobotState();
#
#   if( robot_state == LOST ) {
#     findLine();
#   } else if ( robot_state == ON_LINE ) {
#     followLine();
#   } else if( robot_state == LINE_END ) {
#     celebrate();
#   }
#
#   updateActuators();
# }
# ```
#
# We can also imagine how to clearly extend the above code to include further robot states and behaviours.
